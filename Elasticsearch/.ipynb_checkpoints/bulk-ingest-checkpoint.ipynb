# %%
import sys
from os.path import abspath, join, dirname, exists
# Smart progress bar reader...
import tqdm
import pandas as pd
import json
from sodapy import Socrata
from elasticsearch import Elasticsearch
from elasticsearch.helpers import streaming_bulk

# %%
DATASET_PATH = 'C:/Users/Dean Truong/Jupyter/Elasticsearch/contractors.json'

# %%
def download_dataset():
# Downloads the public dataset if not locally downloaded 
# and returns the number of rows are in the .json file.

    if not exists(DATASET_PATH):
        print("JSON file does not exist...")
        print("Downloading dataset from data.lacity.org...")
        
        client = Socrata("data.lacity.org","8YzE0NUTN2pl4gdOcY5fAquLi",username="dtruong8@toromail.csudh.edu",password="Helloworld123.")
        
        results = client.get("yv23-pmwf",select="distinct contractors_business_name", where="applicant_relationship = 'Contractor'", order="contractors_business_name")
        
        # convert to data frame
        df = pd.DataFrame.from_records(results)
        
        df.to_json(r'C:/Users/Dean Truong/Jupyter/Elasticsearch/contractors.json',orient='records')
        print("Dataset downloaded...")
        
        return df.shape[0]

# %%
def create_index(client):
    """Creates an index in Elasticsearch if one isn't already there."""
    client.indices.create(
        index="contractors",
        body={
            "settings": {"number_of_shards": 1},
            "mappings": {
                "properties": {
                    "names": {"type": "text"},
                }
            },
        },
        ignore=400,
    )

# %%
def generate_actions():
# Reads the file through csv.DictReader() and for each row
# yields a single document. This function is passed into the bulk()
# helper to create many documents in sequence.
    with open(DATASET_PATH, mode="r") as f:
        data = json.load(f)
        f.close()
        i = 0
        for names in data:
            doc = {
                "_id": i + 1,
                "name": names
            }
            i = i + 1
            print(doc)

# %%
def main():
    es = Elasticsearch(['localhost:9200'])
    # print(es.info()) # verification
    
    number_of_docs = download_dataset()
    
    print("Creating index an index...")
    create_index(es)
    
    print("Indexing documents...")
    progress = tqdm.tqdm(unit="docs", total=number_of_docs)
    sucesses = 0
    for ok, action in streaming_bulk(
        es = es, index="contractors", actions=generate_actions(),
    ):

# %%
generate_actions()
# Out:
# {'_id': 2, 'name': {'contractors_business_name': '007 HEATING & AIR'}}
# {'_id': 3, 'name': {'contractors_business_name': '100 PERCENT ELECTRIC'}}
# {'_id': 4, 'name': {'contractors_business_name': '101 CONSTRUCTION'}}
# {'_id': 5, 'name': {'contractors_business_name': '101 PLUMBING REPAIR SERVICE'}}
# {'_id': 6, 'name': {'contractors_business_name': '101 ROOFING & CONSTRUCTION'}}
# {'_id': 7, 'name': {'contractors_business_name': '101 SHEET METAL'}}
# {'_id': 8, 'name': {'contractors_business_name': '1030 N MOUNTAIN AVENUE #174'}}
# {'_id': 9, 'name': {'contractors_business_name': '110 PRO HVAC INC'}}
# {'_id': 10, 'name': {'contractors_business_name': '12178 VAN NUYS BLVD'}}
# {'_id': 11, 'name': {'contractors_business_name': '1 - 2 - 3 PLUMBING & ROOTER'}}
# {'_id': 12, 'name': {'contractors_business_name': '123 RESTORATION SPECIALISTS INC'}}
# {'_id': 13, 'name': {'contractors_business_name': '126 NEW CONSTRUCTION INC'}}
# {'_id': 14, 'name': {'contractors_business_name': '129 BUILDERS INC'}}
# {'_id': 15, 'name': {'contractors_business_name': '12 BRAVO DEVELOPMENT INC'}}
# {'_id': 16, 'name': {'contractors_business_name': '12-GAUGE ELECTRIC INC'}}
# {'_id': 17, 'name': {'contractors_business_name': '12 STEPS CONSTRUCTION'}}
# {'_id': 18, 'name': {'contractors_business_name': '12 TOWERS CONSTRUCTION'}}
# {'_id': 19, 'name': {'contractors_business_name': '12 TOWERS ENGINEERING AND CONSTRUCTION'}}
# {'_id': 20, 'name': {'contractors_business_name': '12 TOWERS INC'}}
# {'_id': 21, 'name': {'contractors_business_name': '13809 FAIRGROVE AVE'}}
# {'_id': 22, 'name': {'contractors_business_name': '15448 ROXFORD ST'}}
# {'_id': 23, 'name': {'contractors_business_name': '168 CONSTRUCTION AND REMODELING'}}
# {'_id': 24, 'name': {'contractors_business_name': '17 DESIGN INCORPORATED'}}
# {'_id': 25, 'name': {'contractors_business_name': '1800COMFORT'}}
# {'_id': 26, 'name': {'contractors_business_name': '1800 THE PLUMBER INC'}}
# {'_id': 27, 'name': {'contractors_business_name': '180 CONSTRUCTION GROUP INC'}}
# {'_id': 28, 'name': {'contractors_business_name': '19 WEST INC'}}
# {'_id': 29, 'name': {'contractors_business_name': '1 AND 1 ELECTRIC INC'}}
# {'_id': 30, 'name': {'contractors_business_name': '1 DAY KITCHEN COUNTERTOPS & TILE CORPORATION'}}
# {'_id': 31, 'name': {'contractors_business_name': '1 DESIGN CONSTRUCTION CORP'}}
# {'_id': 32, 'name': {'contractors_business_name': '1 OAK REMODELING'}}
# {'_id': 33, 'name': {'contractors_business_name': '1ST CHOICE GENERAL SERVICES INC'}}
# {'_id': 34, 'name': {'contractors_business_name': '1ST CHOICE HEATING & AIR CONDITIONING INC'}}
# {'_id': 35, 'name': {'contractors_business_name': '1ST CHOICE PLUMBING'}}
# {'_id': 36, 'name': {'contractors_business_name': '1ST CHOICE ROOFING'}}
# {'_id': 37, 'name': {'contractors_business_name': '1ST - DEMOLITION CO'}}
# {'_id': 38, 'name': {'contractors_business_name': '1ST ENERGY HOME DESIGN INC'}}
# {'_id': 39, 'name': {'contractors_business_name': '1ST LIGHT ENERGY INC'}}
# {'_id': 40, 'name': {'contractors_business_name': '1 STOP BUILDERS'}}
# {'_id': 41, 'name': {'contractors_business_name': '1 STOP BUILDING CONSTRUCTION'}}
# {'_id': 42, 'name': {'contractors_business_name': '1 - STOP ELECTRICAL SERVICE'}}
# {'_id': 43, 'name': {'contractors_business_name': '1 STOP HOME REMODELING INC'}}
# {'_id': 44, 'name': {'contractors_business_name': '1ST PRIME DESIGN CONTRACTORS INC'}}
# {'_id': 45, 'name': {'contractors_business_name': '1ST SKILL CONSTRUCTION SERVICES'}}
# {'_id': 46, 'name': {'contractors_business_name': '1ST TEAM AIR CONDITIONING INC'}}
# {'_id': 47, 'name': {'contractors_business_name': '1ST TOUCH ELECTRIC'}}
# {'_id': 48, 'name': {'contractors_business_name': '1ST TOUCH ELECTRIC INC'}}
# {'_id': 49, 'name': {'contractors_business_name': '1 SUPERIOR ELECTRIC INC'}}
# {'_id': 50, 'name': {'contractors_business_name': '1 TEAMWORK FIRE PROTECTION'}}
# {'_id': 51, 'name': {'contractors_business_name': '2000 CARPET'}}
# {'_id': 52, 'name': {'contractors_business_name': '200 PSI FIRE PROTECTION CO'}}
# {'_id': 53, 'name': {'contractors_business_name': '2010 - AIR'}}
# {'_id': 54, 'name': {'contractors_business_name': '20 / 20 PLUMBING & HEATING INC'}}
# {'_id': 55, 'name': {'contractors_business_name': '20TH CENTURY AIR INC'}}
# {'_id': 56, 'name': {'contractors_business_name': '20TH CENTURY CONSTRUCTION INC'}}
# {'_id': 57, 'name': {'contractors_business_name': '21ST CENTURY ELECTRIC M'}}
# {'_id': 58, 'name': {'contractors_business_name': '21ST CENTURY ELECTRIC M INC'}}
# {'_id': 59, 'name': {'contractors_business_name': '21ST CENTURY NETWORK CABLING'}}
# {'_id': 60, 'name': {'contractors_business_name': '21ST CENTURY REMODELING AND CONSTRUCTION'}}
# {'_id': 61, 'name': {'contractors_business_name': '21ST CENTURY SOLAR'}}
# {'_id': 62, 'name': {'contractors_business_name': '23 1/2 HRS S O S PLUMBING INC'}}
# {'_id': 63, 'name': {'contractors_business_name': '2 & 3 ELECTRIC'}}
# {'_id': 64, 'name': {'contractors_business_name': '23HOURSPLUMBING.COM'}}
# {'_id': 65, 'name': {'contractors_business_name': '24/7 AIR CONDITIONING'}}
# {'_id': 66, 'name': {'contractors_business_name': '24/7 CONSTRUCTION WORKS INC'}}
# {'_id': 67, 'name': {'contractors_business_name': '24 / 7 ELECTRIC'}}
# {'_id': 68, 'name': {'contractors_business_name': '24 / 7 FIRE PROTECTION SERVICES INCORPORATED'}}
# {'_id': 69, 'name': {'contractors_business_name': '24/7 ROOFING SOLUTIONS COMPANY'}}
# {'_id': 70, 'name': {'contractors_business_name': '24 HOUR ROOTER'}}
# {'_id': 71, 'name': {'contractors_business_name': '24 HOUR ROOTER INC'}}
# {'_id': 72, 'name': {'contractors_business_name': '24 HR PLUMBING'}}
# {'_id': 73, 'name': {'contractors_business_name': '24 PREFAB LLC'}}
# {'_id': 74, 'name': {'contractors_business_name': '24 SECURITY FIRE ALARM & ELECTRIC'}}
# {'_id': 75, 'name': {'contractors_business_name': '24 SEVEN'}}
# {'_id': 76, 'name': {'contractors_business_name': '24 SIX CONSTRUCTION INC'}}
# {'_id': 77, 'name': {'contractors_business_name': '2516 W EMPIRE AVE'}}
# {'_id': 78, 'name': {'contractors_business_name': '277 ELECTRIC'}}
# {'_id': 79, 'name': {'contractors_business_name': '2 GROUND ELECTRIC'}}
# {'_id': 80, 'name': {'contractors_business_name': '2H CONSTRUCTION INC'}}
# {'_id': 81, 'name': {'contractors_business_name': "2 INDIAN'S CONSTRUCTION INC"}}
# {'_id': 82, 'name': {'contractors_business_name': '2 KINGS ELECTRIC'}}
# {'_id': 83, 'name': {'contractors_business_name': '2 MG CONSTRUCTION INC'}}
# {'_id': 84, 'name': {'contractors_business_name': '2 P J 2 C AND ASSOCIATES'}}
# {'_id': 85, 'name': {'contractors_business_name': '2 R B BUILDERS CORP'}}
# {'_id': 86, 'name': {'contractors_business_name': '2 THE T CONSTRUCTION'}}
# {'_id': 87, 'name': {'contractors_business_name': '3000 CONSTRUCTION'}}
# {'_id': 88, 'name': {'contractors_business_name': '310 DEVELOPMENT CORPORATION'}}
# {'_id': 89, 'name': {'contractors_business_name': '310 PLUMBING INC'}}
# {'_id': 90, 'name': {'contractors_business_name': '316 ENGINEERING AND CONSTRUCTION CO INC'}}
# {'_id': 91, 'name': {'contractors_business_name': '3.1 CONSTRUCTION'}}
# {'_id': 92, 'name': {'contractors_business_name': '360 CONSTRUCTION GROUP INC'}}
# {'_id': 93, 'name': {'contractors_business_name': '360 CONTRACTORS GROUP INC'}}
# {'_id': 94, 'name': {'contractors_business_name': '360 ELECTRIC'}}
# {'_id': 95, 'name': {'contractors_business_name': '360 ELECTRIC INC'}}
# {'_id': 96, 'name': {'contractors_business_name': '360 HEATING & AIR'}}
# {'_id': 97, 'name': {'contractors_business_name': '360 MANAGEMENT GROUP INC'}}
# {'_id': 98, 'name': {'contractors_business_name': '360 REMODELING INC'}}
# {'_id': 99, 'name': {'contractors_business_name': '360 SOLAR ENERGY INC'}}
# {'_id': 100, 'name': {'contractors_business_name': '365 CONSTRUCTION INC'}}
# {'_id': 101, 'name': {'contractors_business_name': '365 PLUMBING SERVICES INC'}}
# {'_id': 102, 'name': {'contractors_business_name': '38 DEGREES NORTH LATITUDE BUILDERS INC'}}
# {'_id': 103, 'name': {'contractors_business_name': '3 A ROOFING'}}
# {'_id': 104, 'name': {'contractors_business_name': "3 A'S CONSTRUCTION"}}
# {'_id': 105, 'name': {'contractors_business_name': '3C'}}
# {'_id': 106, 'name': {'contractors_business_name': '3 COLOR FLAX LANDSCAPING'}}
# {'_id': 107, 'name': {'contractors_business_name': '3-D CONSTRUCTION'}}
# {'_id': 108, 'name': {'contractors_business_name': '3D CONTRACTORS INC'}}
# {'_id': 109, 'name': {'contractors_business_name': '3-D CONTRUCTION'}}
# {'_id': 110, 'name': {'contractors_business_name': '3 - D FIRE PROTECTION'}}
# {'_id': 111, 'name': {'contractors_business_name': '3 DIM CONSTRUCTION'}}
# {'_id': 112, 'name': {'contractors_business_name': '3 E GROUP INC'}}
# {'_id': 113, 'name': {'contractors_business_name': '3E GROUP INC'}}
# {'_id': 114, 'name': {'contractors_business_name': '3J GENERAL CONSTRUCTION'}}
# {'_id': 115, 'name': {'contractors_business_name': '3 N 1 ELECTRIC INC'}}
# {'_id': 116, 'name': {'contractors_business_name': '3/O ELECTRIC CO'}}
# {'_id': 117, 'name': {'contractors_business_name': '3 PHASE ELECTRIC CO'}}
# {'_id': 118, 'name': {'contractors_business_name': '3 PINOS INC'}}
# {'_id': 119, 'name': {'contractors_business_name': '3RD DIMENSION CONSTRUCTION CORPORATION'}}
# {'_id': 120, 'name': {'contractors_business_name': '3RD GENERATION ROOFING'}}
# {'_id': 121, 'name': {'contractors_business_name': '3R ELECTRIC'}}
# {'_id': 122, 'name': {'contractors_business_name': '3R WOOD DESIGN INC'}}
# {'_id': 123, 'name': {'contractors_business_name': '3 S NETWORK INC'}}
# {'_id': 124, 'name': {'contractors_business_name': '3 THREE STAR CONSTRUCTION'}}
# {'_id': 125, 'name': {'contractors_business_name': '3X SIGNS'}}
# {'_id': 126, 'name': {'contractors_business_name': '4219 BLACKTHORNE AVENUE'}}
# {'_id': 127, 'name': {'contractors_business_name': '480 ELECTRIC'}}
# {'_id': 128, 'name': {'contractors_business_name': '4 ANGELS TABE INC'}}
# {'_id': 129, 'name': {'contractors_business_name': '4 CORNERS REMODELING INC'}}
# {'_id': 130, 'name': {'contractors_business_name': '4D CONSTRUCTION'}}
# {'_id': 131, 'name': {'contractors_business_name': '4 ECO LIVING'}}
# {'_id': 132, 'name': {'contractors_business_name': '4G BUILDERS INC'}}
# {'_id': 133, 'name': {'contractors_business_name': '4 J CONSTRUCTION'}}
# {'_id': 134, 'name': {'contractors_business_name': '4J CONSTRUCTION INC'}}
# {'_id': 135, 'name': {'contractors_business_name': '4OURBATH'}}
# {'_id': 136, 'name': {'contractors_business_name': '4 OVER ELECTRIC'}}
# {'_id': 137, 'name': {'contractors_business_name': '4 OVER ELECTRIC INC'}}
# {'_id': 138, 'name': {'contractors_business_name': '4 S CONSTRUCTION INC'}}
# {'_id': 139, 'name': {'contractors_business_name': '4 SEASONS AIR'}}
# {'_id': 140, 'name': {'contractors_business_name': '4 SEASONS CONSTRUCTION'}}
# {'_id': 141, 'name': {'contractors_business_name': '4 SEASONS CONSTRUCTION INC'}}
# {'_id': 142, 'name': {'contractors_business_name': '4 SEASONS HVAC'}}
# {'_id': 143, 'name': {'contractors_business_name': '4 SEASONS REMODELING & DESIGN INC'}}
# {'_id': 144, 'name': {'contractors_business_name': '4 SEASONS ROOFING'}}
# {'_id': 145, 'name': {'contractors_business_name': '4 SEASONS ROOFING INC'}}
# {'_id': 146, 'name': {'contractors_business_name': '4SITE CONSTRUCTION'}}
# {'_id': 147, 'name': {'contractors_business_name': '4-U CONSTRUCTION INC'}}
# {'_id': 148, 'name': {'contractors_business_name': '4 US IMAGE INC'}}
# {'_id': 149, 'name': {'contractors_business_name': '4WALL ENTERTAINMENT INC'}}
# {'_id': 150, 'name': {'contractors_business_name': '4 X 4 STUDIO'}}
# {'_id': 151, 'name': {'contractors_business_name': '509 CONSTRUCTION'}}
# {'_id': 152, 'name': {'contractors_business_name': '52 STAR CONSTRUCTION'}}
# {'_id': 153, 'name': {'contractors_business_name': '52 STAR CONSTRUCTION INC'}}
# {'_id': 154, 'name': {'contractors_business_name': '562 ELECTRICIAN'}}
# {'_id': 155, 'name': {'contractors_business_name': '568 CONSTRUCTION INC'}}
# {'_id': 156, 'name': {'contractors_business_name': '5 ALARM FIRE CORPORATION'}}
# {'_id': 157, 'name': {'contractors_business_name': '5 POINTS SASH & DOORS'}}
# {'_id': 158, 'name': {'contractors_business_name': '5 STAR BUILDERS INC'}}
# {'_id': 159, 'name': {'contractors_business_name': '5 STAR ELECTRIC'}}
# {'_id': 160, 'name': {'contractors_business_name': '5 STAR ELEVATOR SERVICE INC'}}
# {'_id': 161, 'name': {'contractors_business_name': '5 STAR G DEVELOPMENT & CONSTRUCTION'}}
# {'_id': 162, 'name': {'contractors_business_name': '5 STAR ROOFING'}}
# {'_id': 163, 'name': {'contractors_business_name': '5 TOWERS CONSTRUCTION INC'}}
# {'_id': 164, 'name': {'contractors_business_name': '625 SOUTH MEZA STREET'}}
# {'_id': 165, 'name': {'contractors_business_name': '626 PLUMBING INC'}}
# {'_id': 166, 'name': {'contractors_business_name': '661 ELECTRIC'}}
# {'_id': 167, 'name': {'contractors_business_name': '6TH GENERATION INC'}}
# {'_id': 168, 'name': {'contractors_business_name': '741 W 14TH ST'}}
# {'_id': 169, 'name': {'contractors_business_name': '74 DEGREES HEATING & AIR INC'}}
# {'_id': 170, 'name': {'contractors_business_name': '75 ELECTRICAL SERVICE'}}
# {'_id': 171, 'name': {'contractors_business_name': '75 ELECTRIC INC'}}
# {'_id': 172, 'name': {'contractors_business_name': '770 CONSTRUCTION CORP'}}
# {'_id': 173, 'name': {'contractors_business_name': '777 PAINTING & CONSTRUCTION INC'}}
# {'_id': 174, 'name': {'contractors_business_name': '7 CONSTRUCTION INC'}}
# {'_id': 175, 'name': {'contractors_business_name': '7 ELECTRICAL CONTRACTOR'}}
# {'_id': 176, 'name': {'contractors_business_name': '7 POINT CONSTRUCTION'}}
# {'_id': 177, 'name': {'contractors_business_name': '7 POINT CONSTRUCTION INC'}}
# {'_id': 178, 'name': {'contractors_business_name': '7 STARS CONSTRUCTION & REMODELLING INC'}}
# {'_id': 179, 'name': {'contractors_business_name': '818 ROOFING'}}
# {'_id': 180, 'name': {'contractors_business_name': '8307 ELNORA ST'}}
# {'_id': 181, 'name': {'contractors_business_name': '8401 SEDAN AVE'}}
# {'_id': 182, 'name': {'contractors_business_name': '88 COLLECTIONS INC'}}
# {'_id': 183, 'name': {'contractors_business_name': '88 SIGN CORP'}}
# {'_id': 184, 'name': {'contractors_business_name': '8A CONSTRUCTION'}}
# {'_id': 185, 'name': {'contractors_business_name': '8A GENERAL CONSTRUCTION'}}
# {'_id': 186, 'name': {'contractors_business_name': '911 ELECTRIC'}}
# {'_id': 187, 'name': {'contractors_business_name': '911 ELECTRIC INC'}}
# {'_id': 188, 'name': {'contractors_business_name': '911 PLUMBING'}}
# {'_id': 189, 'name': {'contractors_business_name': '911 PLUMBING & ROOTER'}}
# {'_id': 190, 'name': {'contractors_business_name': '911 PLUMBING SERVICES INC'}}
# {'_id': 191, 'name': {'contractors_business_name': '911 RESTORATION'}}
# {'_id': 192, 'name': {'contractors_business_name': '911 RESTORATION & CONSTRUCTION'}}
# {'_id': 193, 'name': {'contractors_business_name': '911 RESTORATION OF VENTURA'}}
# {'_id': 194, 'name': {'contractors_business_name': '911 ROOTER SERVICES'}}
# {'_id': 195, 'name': {'contractors_business_name': '9 STAR CONSTRUCTION INC'}}
# {'_id': 196, 'name': {'contractors_business_name': '9TH COMMUNICATIONS GROUP'}}
# {'_id': 197, 'name': {'contractors_business_name': 'A 1 A ENGINEERING & CONSTRUCTION INC'}}
# {'_id': 198, 'name': {'contractors_business_name': 'A - 1 ALL AMERICAN ROOFING CO INC'}}
# {'_id': 199, 'name': {'contractors_business_name': 'A - 1 ALL AMERICAN ROOFING W L A INC'}}
# {'_id': 200, 'name': {'contractors_business_name': 'A-1 APACHE PLUMBING'}}
# {'_id': 201, 'name': {'contractors_business_name': 'A - 1 APEX PLUMBING INC'}}
# {'_id': 202, 'name': {'contractors_business_name': 'A1 BUILDERS INC'}}
# {'_id': 203, 'name': {'contractors_business_name': 'A-1 CALIFORNIA BUILDERS'}}
# {'_id': 204, 'name': {'contractors_business_name': 'A - 1 CERTIFIED ELECTRIC INC'}}
# {'_id': 205, 'name': {'contractors_business_name': 'A-1 COAST TEMPORARY SERVICES'}}
# {'_id': 206, 'name': {'contractors_business_name': 'A - 1 CONCRETE & CONSTRUCTION INC'}}
# {'_id': 207, 'name': {'contractors_business_name': 'A - 1 CONSTRUCTION'}}
# {'_id': 208, 'name': {'contractors_business_name': 'A1 CONSTRUCTION'}}
# {'_id': 209, 'name': {'contractors_business_name': 'A 1 CONSTRUCTION & DESIGN INC'}}
# {'_id': 210, 'name': {'contractors_business_name': 'A 1 CONSTRUCTION & DESIGNS INC'}}
# {'_id': 211, 'name': {'contractors_business_name': 'A - 1 CONSTRUCTION INC'}}
# {'_id': 212, 'name': {'contractors_business_name': 'A 1 COPPER REPIPE SPECIALIST'}}
# {'_id': 213, 'name': {'contractors_business_name': 'A-1 ELECTRICAL'}}
# {'_id': 214, 'name': {'contractors_business_name': 'A - 1 ELECTRIC DISCOUNT SERVICE INC'}}
# {'_id': 215, 'name': {'contractors_business_name': 'A-1 ELECTRIC SERVICE COMPANY INC'}}
# {'_id': 216, 'name': {'contractors_business_name': 'A 1 EXTREME BUILDERS INC'}}
# {'_id': 217, 'name': {'contractors_business_name': 'A-1 FIRE PROTECTION INC'}}
# {'_id': 218, 'name': {'contractors_business_name': 'A1 FIRST CLASS CONSTRUCTION'}}
# {'_id': 219, 'name': {'contractors_business_name': 'A - 1 GENERAL BUILDING'}}
# {'_id': 220, 'name': {'contractors_business_name': 'A1 INDUSTRIAL HEATING & COOLING'}}
# {'_id': 221, 'name': {'contractors_business_name': 'A-1 OCEAN BREEZE INC'}}
# {'_id': 222, 'name': {'contractors_business_name': 'A1-PEREZ PLUMBING, ELECTRIC & PIPELINES'}}
# {'_id': 223, 'name': {'contractors_business_name': 'A - 1 PERFORMANCE ROOTER & PLUMBING'}}
# {'_id': 224, 'name': {'contractors_business_name': 'A-1 PLUMBING HEATING & AIR CONDITIONING SERVICES'}}
# {'_id': 225, 'name': {'contractors_business_name': 'A - 1 PLUMBING INC'}}
# {'_id': 226, 'name': {'contractors_business_name': 'A-1 PLUMBING & ROOTER'}}
# {'_id': 227, 'name': {'contractors_business_name': 'A - 1 PLUMBING & ROOTER INC'}}
# {'_id': 228, 'name': {'contractors_business_name': 'A 1 PRECISION BUILDERS'}}
# {'_id': 229, 'name': {'contractors_business_name': 'A 1 PREFERRED ROOFING INC'}}
# {'_id': 230, 'name': {'contractors_business_name': 'A1R KARE PROS'}}
# {'_id': 231, 'name': {'contractors_business_name': 'A - 1 ROOTER & PLUMBING INC'}}
# {'_id': 232, 'name': {'contractors_business_name': 'A - 1 SANDBLASTING & STUCCO CO INC'}}
# {'_id': 233, 'name': {'contractors_business_name': 'A - 1 SERVICE APPLIANCES INC'}}
# {'_id': 234, 'name': {'contractors_business_name': 'A-1 SEWER CONSTRUCTION'}}
# {'_id': 235, 'name': {'contractors_business_name': 'A1 SOLAR POWER INC'}}
# {'_id': 236, 'name': {'contractors_business_name': 'A1 SUPERIOR ROOFING'}}
# {'_id': 237, 'name': {'contractors_business_name': 'A - 1 TOTAL SERVICE CONSTRUCTION INC'}}
# {'_id': 238, 'name': {'contractors_business_name': 'A - 1 TOTAL SERVICE PLUMBING'}}
# {'_id': 239, 'name': {'contractors_business_name': 'A - 26 CONSTRUCTION & ELECTRICAL CONTRACTORS COMPANY'}}
# {'_id': 240, 'name': {'contractors_business_name': 'A 2 C INC'}}
# {'_id': 241, 'name': {'contractors_business_name': 'A 2 Z ELECTRIC'}}
# {'_id': 242, 'name': {'contractors_business_name': 'A2Z ELECTRIC'}}
# {'_id': 243, 'name': {'contractors_business_name': 'A2ZHOME REMODEL & RESTORATION'}}
# {'_id': 244, 'name': {'contractors_business_name': 'A 2 Z PLUMBING SERVICES INC'}}
# {'_id': 245, 'name': {'contractors_business_name': 'A 2 Z SIGN COMPANY'}}
# {'_id': 246, 'name': {'contractors_business_name': 'A - 3 ELECTRIC'}}
# {'_id': 247, 'name': {'contractors_business_name': 'A 5 COMPUTER SERVICES'}}
# {'_id': 248, 'name': {'contractors_business_name': 'A6 PLUMBING INC'}}
# {'_id': 249, 'name': {'contractors_business_name': 'AA1 GRAPHICS & SIGNS'}}
# {'_id': 250, 'name': {'contractors_business_name': 'A A A ACTION INC'}}
# {'_id': 251, 'name': {'contractors_business_name': 'AAA AIR CONDITIONING BEST SERVICE'}}
# {'_id': 252, 'name': {'contractors_business_name': 'A A A ALL STAR CONSTRUCTION INC'}}
# {'_id': 253, 'name': {'contractors_business_name': 'AAA AMERICAN CONSTRUCTION INC'}}
# {'_id': 254, 'name': {'contractors_business_name': 'AAA ARTISTIC ORNAMENTAL IRON WORKS'}}
# {'_id': 255, 'name': {'contractors_business_name': 'A AABBY PLUMBING AND DRAIN'}}
# {'_id': 256, 'name': {'contractors_business_name': 'AAA CALVERT'}}
# {'_id': 257, 'name': {'contractors_business_name': 'AAA COMMERCIAL CONSTRUCTION INC BY KOLLANDER'}}
# {'_id': 258, 'name': {'contractors_business_name': 'A A A CONSTRUCTION AND DEVELOPMENT'}}
# {'_id': 259, 'name': {'contractors_business_name': 'A A A CONSTRUCTION COMPANY'}}
# {'_id': 260, 'name': {'contractors_business_name': 'AAA CONSTRUCTION INC'}}
# {'_id': 261, 'name': {'contractors_business_name': 'AAA DEMOLITION INC'}}
# {'_id': 262, 'name': {'contractors_business_name': 'A A A DEVELOPMENT INC'}}
# {'_id': 263, 'name': {'contractors_business_name': 'A A A ELECTRIC'}}
# {'_id': 264, 'name': {'contractors_business_name': 'A A A ELECTRICAL & COMMUNICATIONS INC'}}
# {'_id': 265, 'name': {'contractors_business_name': 'A A A ELECTRICAL SERVICE GROUP INC'}}
# {'_id': 266, 'name': {'contractors_business_name': 'A A A ELECTRIC & ELEVATOR INC'}}
# {'_id': 267, 'name': {'contractors_business_name': 'AAA EXPERT ROOFING INC'}}
# {'_id': 268, 'name': {'contractors_business_name': 'AAA FIRE PROTECTION CO'}}
# {'_id': 269, 'name': {'contractors_business_name': 'AAA HOUSE PAINTING SERVICES'}}
# {'_id': 270, 'name': {'contractors_business_name': 'A A A LA MAINTENANCE INC'}}
# {'_id': 271, 'name': {'contractors_business_name': 'A A ALLIED CO'}}
# {'_id': 272, 'name': {'contractors_business_name': 'A A ALL PRO CONSTRUCTION'}}
# {'_id': 273, 'name': {'contractors_business_name': 'AA ALL VALLEY PLUMBING'}}
# {'_id': 274, 'name': {'contractors_business_name': 'AAA MASTER BUILDER INC'}}
# {'_id': 275, 'name': {'contractors_business_name': 'AAA NETWORK SOLUTIONS'}}
# {'_id': 276, 'name': {'contractors_business_name': 'AAA PAINTING & CONSTRUCTION'}}
# {'_id': 277, 'name': {'contractors_business_name': 'AAA PARADISE PLUMBING & ROOTER'}}
# {'_id': 278, 'name': {'contractors_business_name': 'A A A PLASTERING'}}
# {'_id': 279, 'name': {'contractors_business_name': 'AAA PLUMBING SOLUTION INC'}}
# {'_id': 280, 'name': {'contractors_business_name': 'A A A PLUMBING SOLUTIONS INC'}}
# {'_id': 281, 'name': {'contractors_business_name': 'A A A PREFERRED PLUMBING INC'}}
# {'_id': 282, 'name': {'contractors_business_name': 'A A A PROPERTY SERVICES'}}
# {'_id': 283, 'name': {'contractors_business_name': 'AAA QUALITY CONSTRUCTION CO'}}
# {'_id': 284, 'name': {'contractors_business_name': 'A A A REMODELING AND CONSTRUCTION'}}
# {'_id': 285, 'name': {'contractors_business_name': 'A A A REMODELING & RESTORATION INC'}}
# {'_id': 286, 'name': {'contractors_business_name': 'A A A ROOFING BY GENE INC'}}
# {'_id': 287, 'name': {'contractors_business_name': 'A A A ROOFING SERVICES'}}
# {'_id': 288, 'name': {'contractors_business_name': 'A A A ROOFING SERVICES INC'}}
# {'_id': 289, 'name': {'contractors_business_name': 'A A A SOLAR ELECTRIC INC'}}
# {'_id': 290, 'name': {'contractors_business_name': 'A A A - VALUE WINDOW SERVICES INC'}}
# {'_id': 291, 'name': {'contractors_business_name': 'AA BAJA CONSTRUCTION'}}
# {'_id': 292, 'name': {'contractors_business_name': 'A A BAJA CONSTRUCTION INC'}}
# {'_id': 293, 'name': {'contractors_business_name': 'AABBY PLUMBING INC'}}
# {'_id': 294, 'name': {'contractors_business_name': 'AABCO WATER HEATERS & SOLAR SERVICES'}}
# {'_id': 295, 'name': {'contractors_business_name': 'A A CALONESTAR ELECTRIC'}}
# {'_id': 296, 'name': {'contractors_business_name': 'A - ACCURATE ROOTER DRAIN CLEANING SERVICE ETC'}}
# {'_id': 297, 'name': {'contractors_business_name': 'A & A CONSTRUCTION'}}
# {'_id': 298, 'name': {'contractors_business_name': 'AAC REMODELING & CONSTRUCTION'}}
# {'_id': 299, 'name': {'contractors_business_name': 'A A C SERVICES INC'}}
# {'_id': 300, 'name': {'contractors_business_name': 'A ACTION FIRE PROTECTION INC'}}
# {'_id': 301, 'name': {'contractors_business_name': 'A & A DESIGN CONSTRUCTION INC'}}
# {'_id': 302, 'name': {'contractors_business_name': 'A & A DEVELOPMENT INC'}}
# {'_id': 303, 'name': {'contractors_business_name': 'A & A ELECTRIC'}}
# {'_id': 304, 'name': {'contractors_business_name': 'A + A ELECTRIC'}}
# {'_id': 305, 'name': {'contractors_business_name': 'A@A ELECTRIC'}}
# {'_id': 306, 'name': {'contractors_business_name': 'A A ELECTRICAL SERVICE'}}
# {'_id': 307, 'name': {'contractors_business_name': 'A A ELECTRICAL SERVICES INC'}}
# {'_id': 308, 'name': {'contractors_business_name': 'A A ELECTRICAL SYSTEMS'}}
# {'_id': 309, 'name': {'contractors_business_name': 'A A ELECTRIC & PLUMBING INC'}}
# {'_id': 310, 'name': {'contractors_business_name': 'A & A ENTERPRISES'}}
# {'_id': 311, 'name': {'contractors_business_name': 'AAE SERVICES INCORPORATED'}}
# {'_id': 312, 'name': {'contractors_business_name': 'A A EXPRESS ELECTRIC'}}
# {'_id': 313, 'name': {'contractors_business_name': 'A A EXPRESS SERVICE'}}
# {'_id': 314, 'name': {'contractors_business_name': 'A & A FIRE PROTECTION'}}
# {'_id': 315, 'name': {'contractors_business_name': 'A A FIRE SYSTEMS INC'}}
# {'_id': 316, 'name': {'contractors_business_name': 'A A G CONSTRUCTION SERVICE INC.'}}
# {'_id': 317, 'name': {'contractors_business_name': 'A A G CONSTRUCTION SERVICES INC'}}
# {'_id': 318, 'name': {'contractors_business_name': 'A & A GENERAL CONSTRUCTION'}}
# {'_id': 319, 'name': {'contractors_business_name': 'A A GOLDEN PLUMBING'}}
# {'_id': 320, 'name': {'contractors_business_name': 'A A G SERVICES INC'}}
# {'_id': 321, 'name': {'contractors_business_name': 'AA HEATING & COOLING'}}
# {'_id': 322, 'name': {'contractors_business_name': 'A-ALL AT EASE ELECTRIC'}}
# {'_id': 323, 'name': {'contractors_business_name': 'A AND A ELECTRICAL SYSTEMS INC'}}
# {'_id': 324, 'name': {'contractors_business_name': 'A AND C ELECTRICAL'}}
# {'_id': 325, 'name': {'contractors_business_name': 'A AND C ROOFING'}}
# {'_id': 326, 'name': {'contractors_business_name': 'A AND F ELECTRIC'}}
# {'_id': 327, 'name': {'contractors_business_name': 'A AND F MCGUIRE ELECTRIC CO'}}
# {'_id': 328, 'name': {'contractors_business_name': 'A AND G AIR SERVICES'}}
# {'_id': 329, 'name': {'contractors_business_name': 'A AND H ELECTRIC COMPANY INC'}}
# {'_id': 330, 'name': {'contractors_business_name': 'A AND J ROOFING'}}
# {'_id': 331, 'name': {'contractors_business_name': 'A AND L SYSTEMS SOLUTIONS'}}
# {'_id': 332, 'name': {'contractors_business_name': 'A AND M CONSTRUCTION'}}
# {'_id': 333, 'name': {'contractors_business_name': 'A AND M CONSTRUCTION INC'}}
# {'_id': 334, 'name': {'contractors_business_name': 'A AND S FIRE PROTECTION INC'}}
# {'_id': 335, 'name': {'contractors_business_name': 'A AND S READE PLUMBING'}}
# {'_id': 336, 'name': {'contractors_business_name': 'A AND S ROOFING INC'}}
# {'_id': 337, 'name': {'contractors_business_name': 'A AND V GLOBAL REMODELING'}}
# {'_id': 338, 'name': {'contractors_business_name': 'A AND V GLOBAL REMODELING INC'}}
# {'_id': 339, 'name': {'contractors_business_name': 'A AND Z PAVING CONTRACTORS INC'}}
# {'_id': 340, 'name': {'contractors_business_name': 'A A P ALL AMERICAN PLUMBING'}}
# {'_id': 341, 'name': {'contractors_business_name': 'A A PHONE & WIRE CO'}}
# {'_id': 342, 'name': {'contractors_business_name': 'A & A PLUMBING'}}
# {'_id': 343, 'name': {'contractors_business_name': 'A & A QUICK COOLING'}}
# {'_id': 344, 'name': {'contractors_business_name': 'AA QUICK COOLING'}}
# {'_id': 345, 'name': {'contractors_business_name': 'A & A QUICK COOLING INC'}}
# {'_id': 346, 'name': {'contractors_business_name': 'AARDVARK ENTERPRISES INC'}}
# {'_id': 347, 'name': {'contractors_business_name': 'AARDVARK GROUP INC THE'}}
# {'_id': 348, 'name': {'contractors_business_name': 'A & A RESTORATION & REMODEL'}}
# {'_id': 349, 'name': {'contractors_business_name': 'AARON ELECTRIC'}}
# {'_id': 350, 'name': {'contractors_business_name': "AARON'S QUALITY PLUMBING"}}
# {'_id': 351, 'name': {'contractors_business_name': "AARON'S QUALITY PLUMBING INC"}}
# {'_id': 352, 'name': {'contractors_business_name': 'A A ROOFING'}}
# {'_id': 353, 'name': {'contractors_business_name': 'AA ROOFING'}}
# {'_id': 354, 'name': {'contractors_business_name': 'AA ROOFING AND WATERPROOF'}}
# {'_id': 355, 'name': {'contractors_business_name': 'A & A ROOFING INC'}}
# {'_id': 356, 'name': {'contractors_business_name': 'AASH CONSTRUCTION INC'}}
# {'_id': 357, 'name': {'contractors_business_name': 'AASHIYANA BUILDERS'}}
# {'_id': 358, 'name': {'contractors_business_name': 'A & A SIGNS CO'}}
# {'_id': 359, 'name': {'contractors_business_name': 'A & A STONE WORKS INC'}}
# {'_id': 360, 'name': {'contractors_business_name': 'A A TECHNOLOGY & ELECTRIC SERVICES'}}
# {'_id': 361, 'name': {'contractors_business_name': 'A & A TOPS'}}
# {'_id': 362, 'name': {'contractors_business_name': 'AA TO ZZ CONSTRUCTION'}}
# {'_id': 363, 'name': {'contractors_business_name': 'A A TWIN BROTHERS PLUMBING'}}
# {'_id': 364, 'name': {'contractors_business_name': 'AA TWIN BROTHERS PLUMBING CORP'}}
# {'_id': 365, 'name': {'contractors_business_name': 'AAVCO ELECTRIC'}}
# {'_id': 366, 'name': {'contractors_business_name': 'A A W CONSTRUCTION'}}
# {'_id': 367, 'name': {'contractors_business_name': 'A A WHYTE #1 PLUMBING'}}
# {'_id': 368, 'name': {'contractors_business_name': 'A A - W L CONST & ELECTRIC'}}
# {'_id': 369, 'name': {'contractors_business_name': 'A B A ALARM COMPANY INC'}}
# {'_id': 370, 'name': {'contractors_business_name': 'A B A CONSTRUCTION'}}
# {'_id': 371, 'name': {'contractors_business_name': 'ABA CONSTRUCTION AND ELECTRIC INC'}}
# {'_id': 372, 'name': {'contractors_business_name': 'ABADAN CO INC'}}
# {'_id': 373, 'name': {'contractors_business_name': 'ABA ELECTRICAL SERVICES INC'}}
# {'_id': 374, 'name': {'contractors_business_name': 'ABARCA CONSTRUCTION'}}
# {'_id': 375, 'name': {'contractors_business_name': 'A B & A TEST COMPANY INC'}}
# {'_id': 376, 'name': {'contractors_business_name': 'ABBA COMMUNICATIONS'}}
# {'_id': 377, 'name': {'contractors_business_name': 'A B B CONSTRUCTION CORP'}}
# {'_id': 378, 'name': {'contractors_business_name': 'ABBEY ACCESS GROUP'}}
# {'_id': 379, 'name': {'contractors_business_name': 'ABBOTT J R CONSTRUCTION INC'}}
# {'_id': 380, 'name': {'contractors_business_name': 'ABBOTT R T CONSTRUCTION INC'}}
# {'_id': 381, 'name': {'contractors_business_name': 'A & B BUILDING SERVICE'}}
# {'_id': 382, 'name': {'contractors_business_name': 'ABBY B H CONSTRUCTION'}}
# {'_id': 383, 'name': {'contractors_business_name': 'A B C'}}
# {'_id': 384, 'name': {'contractors_business_name': 'ABC-ADVANCE BUILDER & CONSTRUCTOR'}}
# {'_id': 385, 'name': {'contractors_business_name': 'A B C ADVANCE BUILDER & CONSTRUCTOR INC'}}
# {'_id': 386, 'name': {'contractors_business_name': "A B C AGUERO'S BUILDERS COMPANY INC"}}
# {'_id': 387, 'name': {'contractors_business_name': 'A B C ART BUILDER CONSTRUCTION'}}
# {'_id': 388, 'name': {'contractors_business_name': 'A B CASTLE BUILDING CONTRACTOR INC'}}
# {'_id': 389, 'name': {'contractors_business_name': 'A B C COMMERCIAL ROOFING'}}
# {'_id': 390, 'name': {'contractors_business_name': 'A B C CONSTRUCTION CO'}}
# {'_id': 391, 'name': {'contractors_business_name': 'A B C CONSTRUCTION & DESIGN'}}
# {'_id': 392, 'name': {'contractors_business_name': 'A B C CONSTRUCTION & DESIGN_HOME BEAUTIFICATION'}}
# {'_id': 393, 'name': {'contractors_business_name': 'A B C CONSTRUCTION NEWHOME REMODELING & ROOM ADDITION'}}
# {'_id': 394, 'name': {'contractors_business_name': 'A B C D BUILDERS INC'}}
# {'_id': 395, 'name': {'contractors_business_name': 'A B C ELECTRIC'}}
# {'_id': 396, 'name': {'contractors_business_name': 'ABC ELECTRICAL ENTERPRISES INC'}}
# {'_id': 397, 'name': {'contractors_business_name': 'A B C ELECTRICS COMPANY'}}
# {'_id': 398, 'name': {'contractors_business_name': 'ABC ELECTRICS COMPANY INC'}}
# {'_id': 399, 'name': {'contractors_business_name': 'ABC ENERGY SOLUTIONS'}}
# {'_id': 400, 'name': {'contractors_business_name': 'A B C FIRE PROTECTION'}}
# {'_id': 401, 'name': {'contractors_business_name': 'ABC HOME BUILDERS'}}
# {'_id': 402, 'name': {'contractors_business_name': 'ABC HOME BUILDERS INC'}}
# {'_id': 403, 'name': {'contractors_business_name': 'ABC MANAGEMENT'}}
# {'_id': 404, 'name': {'contractors_business_name': 'ABCOMM'}}
# {'_id': 405, 'name': {'contractors_business_name': 'A & B CONSTRUCTION'}}
# {'_id': 406, 'name': {'contractors_business_name': 'A B CONSTRUCTION'}}
# {'_id': 407, 'name': {'contractors_business_name': 'A B CONSTRUCTION CO'}}
# {'_id': 408, 'name': {'contractors_business_name': 'A B CONSTRUCTION & RESTORATION INC'}}
# {'_id': 409, 'name': {'contractors_business_name': 'A B CONTRACTORS AND HANDYMAN INC'}}
# {'_id': 410, 'name': {'contractors_business_name': 'A B C O PACIFIC BUILDERS INC'}}
# {'_id': 411, 'name': {'contractors_business_name': 'ABCREMODEL INC'}}
# {'_id': 412, 'name': {'contractors_business_name': 'A B C RESTAURANT EQUIPMENT CO'}}
# {'_id': 413, 'name': {'contractors_business_name': 'A B C ROOFING'}}
# {'_id': 414, 'name': {'contractors_business_name': 'A B C SIGN SERVICE'}}
# {'_id': 415, 'name': {'contractors_business_name': 'ABC SOLAR INCORPORATED'}}
# {'_id': 416, 'name': {'contractors_business_name': 'A B C WATERPROOFING'}}
# {'_id': 417, 'name': {'contractors_business_name': 'ABDERRAZAK BOUARADA'}}
# {'_id': 418, 'name': {'contractors_business_name': 'A B DESIGN & REMODELING CONSULTING INC'}}
# {'_id': 419, 'name': {'contractors_business_name': 'A B E ANTHONY CONST'}}
# {'_id': 420, 'name': {'contractors_business_name': 'ABECO ELECTRIC SERVICE INC'}}
# {'_id': 421, 'name': {'contractors_business_name': 'A B E CONTRACTORS INC'}}
# {'_id': 422, 'name': {'contractors_business_name': 'ABE ELECTRIC INC'}}
# {'_id': 423, 'name': {'contractors_business_name': 'ABELAR PAT'}}
# {'_id': 424, 'name': {'contractors_business_name': 'ABEL AUDIO'}}
# {'_id': 425, 'name': {'contractors_business_name': 'ABEL BUILDERS INC GENERAL CONTRACTORS'}}
# {'_id': 426, 'name': {'contractors_business_name': 'A B ELECTRIC INC'}}
# {'_id': 427, 'name': {'contractors_business_name': 'A B ELECTRONICS INC'}}
# {'_id': 428, 'name': {'contractors_business_name': 'ABELIAN HAMAIAK'}}
# {'_id': 429, 'name': {'contractors_business_name': 'ABE LINCOLN PLUMBING'}}
# {'_id': 430, 'name': {'contractors_business_name': 'A BELLA CASA CONSTRUCTION'}}
# {'_id': 431, 'name': {'contractors_business_name': 'ABELL ELEVATOR INTERNATIONAL OF CALIFORNIA LLC'}}
# {'_id': 432, 'name': {'contractors_business_name': 'ABEL PLUMBING'}}
# {'_id': 433, 'name': {'contractors_business_name': "ABEL'S CONSTRUCTION"}}
# {'_id': 434, 'name': {'contractors_business_name': "ABEL'S CONSTRUCTION INC"}}
# {'_id': 435, 'name': {'contractors_business_name': 'ABENOJA DEMOSTHENES'}}
# {'_id': 436, 'name': {'contractors_business_name': 'A B E PLUMBING HEATING & AIR'}}
# {'_id': 437, 'name': {'contractors_business_name': "ABE'S ELECTRIC"}}
# {'_id': 438, 'name': {'contractors_business_name': 'A - BEST REMODELING'}}
# {'_id': 439, 'name': {'contractors_business_name': 'A BETTER DEAL INC'}}
# {'_id': 440, 'name': {'contractors_business_name': 'A B F AMERICAN CONSTRUCTION GROUP INC'}}
# {'_id': 441, 'name': {'contractors_business_name': 'A B F CONSTRUCTION'}}
# {'_id': 442, 'name': {'contractors_business_name': 'A B FIRE PROTECTION INC'}}
# {'_id': 443, 'name': {'contractors_business_name': 'A B G CONSTRUCTION'}}
# {'_id': 444, 'name': {'contractors_business_name': 'ABG CONSTRUCTION & RESTORATION'}}
# {'_id': 445, 'name': {'contractors_business_name': 'A & B GENERAL CONTRACTORS CO'}}
# {'_id': 446, 'name': {'contractors_business_name': 'A & B GLASS'}}
# {'_id': 447, 'name': {'contractors_business_name': 'A B G PLUMBING & ROOTER'}}
# {'_id': 448, 'name': {'contractors_business_name': 'A B H CONSTRUCTION AND MAINTENANCE'}}
# {'_id': 449, 'name': {'contractors_business_name': 'A B H PLUMBING INC'}}
# {'_id': 450, 'name': {'contractors_business_name': 'A B I CONSTRUCTION & ELECTRIC INC'}}
# {'_id': 451, 'name': {'contractors_business_name': 'ABIEL STRUCTURAL INC'}}
# {'_id': 452, 'name': {'contractors_business_name': 'ABILITY CONTRACTORS'}}
# {'_id': 453, 'name': {'contractors_business_name': 'ABILITY HEATING & AIR CONDITIONING'}}
# {'_id': 454, 'name': {'contractors_business_name': 'ABILITY NETWORK & TELEPHONE INC'}}
# {'_id': 455, 'name': {'contractors_business_name': 'ABILITY PLUMBING'}}
# {'_id': 456, 'name': {'contractors_business_name': 'ABI-NAJM JOHNNY T'}}
# {'_id': 457, 'name': {'contractors_business_name': 'ABLE AIR CONDITIONING'}}
# {'_id': 458, 'name': {'contractors_business_name': 'ABLE AIR SERVICES'}}
# {'_id': 459, 'name': {'contractors_business_name': 'ABLE CONSTRUCTION & ELECTRIC INC'}}
# {'_id': 460, 'name': {'contractors_business_name': 'ABLE FIRE PROTECTION COMPANY'}}
# {'_id': 461, 'name': {'contractors_business_name': 'ABLE LIFT INC'}}
# {'_id': 462, 'name': {'contractors_business_name': 'ABLE PLUMBING'}}
# {'_id': 463, 'name': {'contractors_business_name': 'ABLTECH INC'}}
# {'_id': 464, 'name': {'contractors_business_name': 'A & B MAINTENANCE AND GENERAL CONTRACTORS'}}
# {'_id': 465, 'name': {'contractors_business_name': 'A B M BUILDING SOLUTIONS LLC'}}
# {'_id': 466, 'name': {'contractors_business_name': 'ABM ELECTRICAL & LIGHTING SOLUTIONS INC'}}
# {'_id': 467, 'name': {'contractors_business_name': 'ABM ELECTRICAL POWER SERVICES LLC'}}
# {'_id': 468, 'name': {'contractors_business_name': 'A B M HEATING & A / C INC'}}
# {'_id': 469, 'name': {'contractors_business_name': 'A B M SERVICES'}}
# {'_id': 470, 'name': {'contractors_business_name': 'ABOVE ALL ELECTRIC'}}
# {'_id': 471, 'name': {'contractors_business_name': 'ABOVE ALL ROOFING'}}
# {'_id': 472, 'name': {'contractors_business_name': 'ABOVE ALL ROOFING INC'}}
# {'_id': 473, 'name': {'contractors_business_name': 'ABOVE IT ALL ROOFING'}}
# {'_id': 474, 'name': {'contractors_business_name': 'ABOVE IT ALL ROOFING COMPANY'}}
# {'_id': 475, 'name': {'contractors_business_name': 'ABOVE IT ALL ROOFING INC'}}
# {'_id': 476, 'name': {'contractors_business_name': 'ABOVE THE LEVEL CONSTRUCTION INC'}}
# {'_id': 477, 'name': {'contractors_business_name': "A B PADILLA'S ELECTRIC INC"}}
# {'_id': 478, 'name': {'contractors_business_name': 'ABP ELECTRIC CORP'}}
# {'_id': 479, 'name': {'contractors_business_name': 'A B PLASTERING CORP'}}
# {'_id': 480, 'name': {'contractors_business_name': 'A - B PLUMBING'}}
# {'_id': 481, 'name': {'contractors_business_name': 'A B PLUMBING CONTRACTOR INC'}}
# {'_id': 482, 'name': {'contractors_business_name': 'A & B PLUMBING HEATING ELECTRICAL'}}
# {'_id': 483, 'name': {'contractors_business_name': 'A B PLUMBING & HEATING INC'}}
# {'_id': 484, 'name': {'contractors_business_name': 'A B PLUMBING & HEATING  INC'}}
# {'_id': 485, 'name': {'contractors_business_name': 'ABRAHAM CHAIM SCHKALIM'}}
# {'_id': 486, 'name': {'contractors_business_name': 'ABRAHAM ELECTRIC'}}
# {'_id': 487, 'name': {'contractors_business_name': 'ABRAHAM GEORGE'}}
# {'_id': 488, 'name': {'contractors_business_name': 'ABRAHAMIAN SEROUJ'}}
# {'_id': 489, 'name': {'contractors_business_name': 'ABRAMIAN VARTAN'}}
# {'_id': 490, 'name': {'contractors_business_name': 'ABRAMYAN JOHN ELECTRIC AND CONSTRUCTION'}}
# {'_id': 491, 'name': {'contractors_business_name': 'ABRARY HOUSHMAND'}}
# {'_id': 492, 'name': {'contractors_business_name': "ABREGO'S ROOFING"}}
# {'_id': 493, 'name': {'contractors_business_name': 'ABREM GENERAL CONTRACTOR & ELECTRICAL INC'}}
# {'_id': 494, 'name': {'contractors_business_name': 'ABRIL JESUS JR'}}
# {'_id': 495, 'name': {'contractors_business_name': 'A B S CONSTRUCTION GROUP INC'}}
# {'_id': 496, 'name': {'contractors_business_name': 'ABS ELECTRIC INC'}}
# {'_id': 497, 'name': {'contractors_business_name': 'A B S INTERNET'}}
# {'_id': 498, 'name': {'contractors_business_name': 'ABSOLUTE BEST SERVICE PLUMBING INC'}}
# {'_id': 499, 'name': {'contractors_business_name': 'ABSOLUTE CONSTRUCTION'}}
# {'_id': 500, 'name': {'contractors_business_name': 'ABSOLUTE CONSTRUCTION INC'}}
# {'_id': 501, 'name': {'contractors_business_name': 'ABSOLUTE ELECTRIC'}}
# {'_id': 502, 'name': {'contractors_business_name': 'ABSOLUTE FIRE PROTECTION INC'}}
# {'_id': 503, 'name': {'contractors_business_name': 'ABSOLUTELY SOLAR ELECTRIC'}}
# {'_id': 504, 'name': {'contractors_business_name': 'ABSOLUTELY SOLAR INC'}}
# {'_id': 505, 'name': {'contractors_business_name': 'ABSOLUTE PLUMBING AND ROOTING'}}
# {'_id': 506, 'name': {'contractors_business_name': 'ABSOLUTE POWER SYSTEMS'}}
# {'_id': 507, 'name': {'contractors_business_name': 'ABSOLUTE REMODELING INC'}}
# {'_id': 508, 'name': {'contractors_business_name': 'ABSOLUTE SECURITY AND TECHNOLOGIES INC'}}
# {'_id': 509, 'name': {'contractors_business_name': 'ABSOLUTE SECURITY SYSTEMS'}}
# {'_id': 510, 'name': {'contractors_business_name': 'ABSOLUTE SIGN INC'}}
# {'_id': 511, 'name': {'contractors_business_name': 'ABSOLUTE SYSTEMS'}}
# {'_id': 512, 'name': {'contractors_business_name': 'A B & SONS ELECTRICAL CO'}}
# {'_id': 513, 'name': {'contractors_business_name': 'A B & SONS ELECTRICAL CO.'}}
# {'_id': 514, 'name': {'contractors_business_name': 'A B S SHORING INC'}}
# {'_id': 515, 'name': {'contractors_business_name': 'A B S TECHNICAL ELECTRIC INC'}}
# {'_id': 516, 'name': {'contractors_business_name': 'ABSTRACT POOL DESIGNS'}}
# {'_id': 517, 'name': {'contractors_business_name': 'A B TILE WORKS INC'}}
# {'_id': 518, 'name': {'contractors_business_name': 'A B T PLUMBING AND ROOTER'}}
# {'_id': 519, 'name': {'contractors_business_name': 'A BUILDING CONCEPT'}}
# {'_id': 520, 'name': {'contractors_business_name': 'A BUNDCHI ELECTRICAL COMPANY'}}
# {'_id': 521, 'name': {'contractors_business_name': 'ABUNDIS FRANKLIN CODY'}}
# {'_id': 522, 'name': {'contractors_business_name': 'ABURTO MIGUEL ANGEL'}}
# {'_id': 523, 'name': {'contractors_business_name': 'ACABE GENERAL CONTRACTOR'}}
# {'_id': 524, 'name': {'contractors_business_name': 'ACADEMY ELECTRIC INC'}}
# {'_id': 525, 'name': {'contractors_business_name': 'ACADEMY ROOF CORP'}}
# {'_id': 526, 'name': {'contractors_business_name': 'ACADIAN DEVELOPMENT INC'}}
# {'_id': 527, 'name': {'contractors_business_name': 'A C ALL STAR'}}
# {'_id': 528, 'name': {'contractors_business_name': "A + CAL'S CONSTRUCTION"}}
# {'_id': 529, 'name': {'contractors_business_name': 'A CANCHAN CORPORATION'}}
# {'_id': 530, 'name': {'contractors_business_name': 'AC BLUE AIR HTG'}}
# {'_id': 531, 'name': {'contractors_business_name': 'A C BUILDERS & CONSULTANTS INC'}}
# {'_id': 532, 'name': {'contractors_business_name': 'ACC'}}
# {'_id': 533, 'name': {'contractors_business_name': 'A C CABLING'}}
# {'_id': 534, 'name': {'contractors_business_name': 'A C CABLING INC'}}
# {'_id': 535, 'name': {'contractors_business_name': 'ACCEL BUILDERS INC'}}
# {'_id': 536, 'name': {'contractors_business_name': 'ACCEL DEVELOPMENT'}}
# {'_id': 537, 'name': {'contractors_business_name': 'ACCELERATE CONSTRUCTION INC'}}
# {'_id': 538, 'name': {'contractors_business_name': 'ACCELERATED BUILDERS'}}
# {'_id': 539, 'name': {'contractors_business_name': 'ACCELERATED MODULAR CONCEPTS INC'}}
# {'_id': 540, 'name': {'contractors_business_name': 'ACCEND ENERGY INC'}}
# {'_id': 541, 'name': {'contractors_business_name': 'ACCENT AUTOMATION'}}
# {'_id': 542, 'name': {'contractors_business_name': 'ACCENT FLAG & SIGN SERVICE'}}
# {'_id': 543, 'name': {'contractors_business_name': 'ACCENT PLUMBING INC'}}
# {'_id': 544, 'name': {'contractors_business_name': 'ACCESS CONSTRUCTION REMODELING'}}
# {'_id': 545, 'name': {'contractors_business_name': 'ACCESS ELECTRIC INC'}}
# {'_id': 546, 'name': {'contractors_business_name': 'ACCESS FIVE COMMUNICATIONS INC'}}
# {'_id': 547, 'name': {'contractors_business_name': 'ACCESS HEATING & COOLING'}}
# {'_id': 548, 'name': {'contractors_business_name': 'ACCESSIBLE BUILDING & DESIGN'}}
# {'_id': 549, 'name': {'contractors_business_name': 'ACCESSIBLE CONSTRUCTION'}}
# {'_id': 550, 'name': {'contractors_business_name': 'ACCESS PACIFIC INC'}}
# {'_id': 551, 'name': {'contractors_business_name': 'ACCESS PLUMBING & ROOTER SERVICES'}}
# {'_id': 552, 'name': {'contractors_business_name': 'ACCESS SECURITY CONTROLS INTERNATIONAL INC'}}
# {'_id': 553, 'name': {'contractors_business_name': 'ACCION ELECTRIC'}}
# {'_id': 554, 'name': {'contractors_business_name': 'AC & C NETWORK SERVICES'}}
# {'_id': 555, 'name': {'contractors_business_name': 'ACCO ENGINEERED SYSTEMS INC'}}
# {'_id': 556, 'name': {'contractors_business_name': 'ACCO ENGINEERED SYSTEMS INC.'}}
# {'_id': 557, 'name': {'contractors_business_name': 'ACCOLADE ELECTRIC INC'}}
# {'_id': 558, 'name': {'contractors_business_name': 'ACCOM CONSTRUCTION'}}
# {'_id': 559, 'name': {'contractors_business_name': 'A C COMMUNICATIONS'}}
# {'_id': 560, 'name': {'contractors_business_name': 'A & C CONSTRUCTION'}}
# {'_id': 561, 'name': {'contractors_business_name': 'A / C CONTROL INC'}}
# {'_id': 562, 'name': {'contractors_business_name': 'A C COOL'}}
# {'_id': 563, 'name': {'contractors_business_name': 'ACCORD ELECTRICAL CORPORATION'}}
# {'_id': 564, 'name': {'contractors_business_name': 'ACCORD ELECTRICAL SERVICE'}}
# {'_id': 565, 'name': {'contractors_business_name': 'ACCORD ELECTRIC CORPORATION'}}
# {'_id': 566, 'name': {'contractors_business_name': 'ACCORINTI SERSE'}}
# {'_id': 567, 'name': {'contractors_business_name': 'ACCOUNTABLE AIR CONDITIONING INCORPORATED'}}
# {'_id': 568, 'name': {'contractors_business_name': 'A C & C PLUMBING'}}
# {'_id': 569, 'name': {'contractors_business_name': 'ACCS ELECTRIC INC'}}
# {'_id': 570, 'name': {'contractors_business_name': 'ACCULECTRIC'}}
# {'_id': 571, 'name': {'contractors_business_name': 'ACCURATE AIR CONDITIONING AND HEATING INC'}}
# {'_id': 572, 'name': {'contractors_business_name': 'ACCURATE AIR SYSTEMS'}}
# {'_id': 573, 'name': {'contractors_business_name': 'ACCURATE BUILDERS & REPAIR'}}
# {'_id': 574, 'name': {'contractors_business_name': 'ACCURATE CLIMATE CONTROL'}}
# {'_id': 575, 'name': {'contractors_business_name': 'ACCURATE CONSTRUCTION'}}
# {'_id': 576, 'name': {'contractors_business_name': 'ACCURATE CONSTRUCTION COMPANY INC'}}
# {'_id': 577, 'name': {'contractors_business_name': 'ACCURATE CONSTRUCTION COMPANY INC.'}}
# {'_id': 578, 'name': {'contractors_business_name': 'ACCURATE CONTRACTING INC'}}
# {'_id': 579, 'name': {'contractors_business_name': 'ACCURATE ELECTRIC CO'}}
# {'_id': 580, 'name': {'contractors_business_name': 'ACCURATE HEATING AND AIR CONDITIONING'}}
# {'_id': 581, 'name': {'contractors_business_name': 'ACCURATE HEATING AND AIR CONDITIONING LLC'}}
# {'_id': 582, 'name': {'contractors_business_name': 'ACCURATE HS INC'}}
# {'_id': 583, 'name': {'contractors_business_name': 'ACCURATE INSTALL INC'}}
# {'_id': 584, 'name': {'contractors_business_name': 'ACCURATE PAINTING & CONSTRUCTION CO'}}
# {'_id': 585, 'name': {'contractors_business_name': 'ACCURATE PLUMBING'}}
# {'_id': 586, 'name': {'contractors_business_name': 'ACCURATE PLUMBING AND DRAINS'}}
# {'_id': 587, 'name': {'contractors_business_name': 'ACCURATE POWER SOLUTIONS'}}
# {'_id': 588, 'name': {'contractors_business_name': 'ACCURATE ROOFING'}}
# {'_id': 589, 'name': {'contractors_business_name': 'ACCURATE ROOFING COMPANY'}}
# {'_id': 590, 'name': {'contractors_business_name': 'ACCURATE ROOFING SOLUTIONS'}}
# {'_id': 591, 'name': {'contractors_business_name': 'ACCURATE SECURITY LOCK & SAFE'}}
# {'_id': 592, 'name': {'contractors_business_name': 'ACCURATE ZONE HEATING AND AIR CONDITIONING'}}
# {'_id': 593, 'name': {'contractors_business_name': 'ACCU SERVICE CONSTRUCTION INC'}}
# {'_id': 594, 'name': {'contractors_business_name': 'ACCUTHERM REFRIGERATION INC'}}
# {'_id': 595, 'name': {'contractors_business_name': 'A C DAVE HEATING & AIR'}}
# {'_id': 596, 'name': {'contractors_business_name': 'A C - D C AUTOMATION INC'}}
# {'_id': 597, 'name': {'contractors_business_name': 'AC/DC ELECTRIC PROS INC'}}
# {'_id': 598, 'name': {'contractors_business_name': 'A C D C GENERAL ELECTRIC'}}
# {'_id': 599, 'name': {'contractors_business_name': 'A C - D C SOLUTIONS INC'}}
# {'_id': 600, 'name': {'contractors_business_name': 'A C D D INC'}}
# {'_id': 601, 'name': {'contractors_business_name': 'A C DEVELOPMENT CO'}}
# {'_id': 602, 'name': {'contractors_business_name': 'A C DOCTOR - HEATING & AIR CONDITIONING CO'}}
# {'_id': 603, 'name': {'contractors_business_name': 'ACE-1 ELECTRIC'}}
# {'_id': 604, 'name': {'contractors_business_name': 'ACE AIR CONDITIONING'}}
# {'_id': 605, 'name': {'contractors_business_name': 'ACE ALARM SYSTEMS'}}
# {'_id': 606, 'name': {'contractors_business_name': 'ACE ALLIED INC'}}
# {'_id': 607, 'name': {'contractors_business_name': 'ACE APPLIANCE HEATING AND COOLING'}}
# {'_id': 608, 'name': {'contractors_business_name': 'ACE AWNING INC'}}
# {'_id': 609, 'name': {'contractors_business_name': 'ACE BLUE CONSTRUCTION INC'}}
# {'_id': 610, 'name': {'contractors_business_name': 'ACE BOILER CO'}}
# {'_id': 611, 'name': {'contractors_business_name': 'ACE BUILDING AND DRYWALL CONSTRUCTION'}}
# {'_id': 612, 'name': {'contractors_business_name': 'ACE CABLING SOLUTIONS'}}
# {'_id': 613, 'name': {'contractors_business_name': 'A C E CARE INC'}}
# ...
# {'_id': 804, 'name': {'contractors_business_name': 'ADD PLUMBING INC'}}
# {'_id': 805, 'name': {'contractors_business_name': 'ADDSCAPE INC'}}
# {'_id': 806, 'name': {'contractors_business_name': 'A D E C INC'}}
# {'_id': 807, 'name': {'contractors_business_name': 'ADEE BOB PLBG & HTG'}}
# {'_id': 808, 'name': {'contractors_business_name': 'ADEEDO'}}
# {'_id': 809, 'name': {'contractors_business_name': 'ADEE PLUMBING AND HEATING INC'}}
# {'_id': 810, 'name': {'contractors_business_name': 'ADEL ALLEN'}}
# {'_id': 811, 'name': {'contractors_business_name': 'A D ELECTRIC'}}
# {'_id': 812, 'name': {'contractors_business_name': 'AD ELECTRICAL ADVERTISING INC'}}
# {'_id': 813, 'name': {'contractors_business_name': 'A & D ELECTRICAL INC'}}
# {'_id': 814, 'name': {'contractors_business_name': 'A & D ELECTRICAL INC DBA TRUST ELECTRICAL'}}
# {'_id': 815, 'name': {'contractors_business_name': 'A & D ELECTRICAL INCORPORATED'}}
# {'_id': 816, 'name': {'contractors_business_name': 'A&D ELECTRICAL INCORPORATED DBA TRUST'}}
# {'_id': 817, 'name': {'contractors_business_name': 'A & D ELECTRICAL INCORPORATED DBA TRUST ELECTRIC'}}
# {'_id': 818, 'name': {'contractors_business_name': 'A D ELECTRIC VOICE AND DATA'}}
# {'_id': 819, 'name': {'contractors_business_name': 'ADELSON DAVID A HEATING & AIR CONDITIONING'}}
# {'_id': 820, 'name': {'contractors_business_name': 'ADEM PAUL D'}}
# {'_id': 821, 'name': {'contractors_business_name': 'ADEPT PLUMBING COMPANY'}}
# {'_id': 822, 'name': {'contractors_business_name': 'A DESIGN BUILD GROUP'}}
# {'_id': 823, 'name': {'contractors_business_name': 'A & D FIRE PROTECTION INC'}}
# {'_id': 824, 'name': {'contractors_business_name': 'A & D FIRE SPRINKLERS INC'}}
# {'_id': 825, 'name': {'contractors_business_name': 'A D G CONSTRUCTION AND ROOFING'}}
# {'_id': 826, 'name': {'contractors_business_name': 'A & D GENERAL BUILDERS INC'}}
# {'_id': 827, 'name': {'contractors_business_name': 'A D G INC'}}
# {'_id': 828, 'name': {'contractors_business_name': 'ADIA INDUSTRIAL SERVICES LLC'}}
# {'_id': 829, 'name': {'contractors_business_name': 'A DIAMOND AFFAIR LUXURY HOMES'}}
# {'_id': 830, 'name': {'contractors_business_name': 'ADI ELECTRICAL SERVICES'}}
# {'_id': 831, 'name': {'contractors_business_name': 'ADI ELECTRICAL SERVICES INC'}}
# {'_id': 832, 'name': {'contractors_business_name': 'ADIKAR SEVAN'}}
# {'_id': 833, 'name': {'contractors_business_name': 'ADIMPACT CORPORATE SIGNAGE'}}
# {'_id': 834, 'name': {'contractors_business_name': 'ADITAN,  A DIVISION OF SOCAL CONSTRUCTION AND REMODELING INC'}}
# {'_id': 835, 'name': {'contractors_business_name': 'ADJUST COMFORT HEATING / AIR CONDITIONING'}}
# {'_id': 836, 'name': {'contractors_business_name': 'ADKISSON ELECTRIC'}}
# {'_id': 837, 'name': {'contractors_business_name': 'ADLER KIEF INC'}}
# {'_id': 838, 'name': {'contractors_business_name': 'A D L PLUMBING'}}
# {'_id': 839, 'name': {'contractors_business_name': 'A D M CONSTRUCTION CO'}}
# {'_id': 840, 'name': {'contractors_business_name': 'ADMIRAL REFRIGERATION INC'}}
# {'_id': 841, 'name': {'contractors_business_name': 'ADMIRE ROOFING'}}
# {'_id': 842, 'name': {'contractors_business_name': 'ADNA CINSTRUCTION INC'}}
# {'_id': 843, 'name': {'contractors_business_name': 'ADNAN MOHAMED'}}
# {'_id': 844, 'name': {'contractors_business_name': 'ADNAN MOHAMED ALJOJO'}}
# {'_id': 845, 'name': {'contractors_business_name': 'A D N PLUMBING'}}
# {'_id': 846, 'name': {'contractors_business_name': 'ADOBE BUILDERS'}}
# {'_id': 847, 'name': {'contractors_business_name': 'ADOBE BUILDERS INC'}}
# {'_id': 848, 'name': {'contractors_business_name': 'ADOBE CONSTRUCTION'}}
# {'_id': 849, 'name': {'contractors_business_name': 'ADOLFOS CONSTRUCTION'}}
# {'_id': 850, 'name': {'contractors_business_name': "ADOLFO'S CONTRACTOR CORPORATION"}}
# {'_id': 851, 'name': {'contractors_business_name': 'ADORA - BILT HOMES'}}
# {'_id': 852, 'name': {'contractors_business_name': 'ADORBEHI PARVIZ'}}
# {'_id': 853, 'name': {'contractors_business_name': 'ADORN CONSTRUCTION'}}
# {'_id': 854, 'name': {'contractors_business_name': 'A D PLUMBING'}}
# {'_id': 855, 'name': {'contractors_business_name': 'A D PLUMBING CO.'}}
# {'_id': 856, 'name': {'contractors_business_name': 'A D PLUMBING SERVICE INC'}}
# {'_id': 857, 'name': {'contractors_business_name': 'A D P MASTER BUILDERS'}}
# {'_id': 858, 'name': {'contractors_business_name': 'A & D QUALITY BUILDERS AND DEVELOPER INC'}}
# {'_id': 859, 'name': {'contractors_business_name': 'A - DRAINS PLUMBING AND ROOTER INC'}}
# {'_id': 860, 'name': {'contractors_business_name': 'A-DRAINS PLUMBING AND ROOTER INC'}}
# {'_id': 861, 'name': {'contractors_business_name': 'ADR CONSTRUCTION'}}
# {'_id': 862, 'name': {'contractors_business_name': 'ADR CONSTRUCTION DESIGN'}}
# {'_id': 863, 'name': {'contractors_business_name': 'A D R CONSTRUCTION INC'}}
# {'_id': 864, 'name': {'contractors_business_name': 'A D R ELECTRIC'}}
# {'_id': 865, 'name': {'contractors_business_name': 'ADRIAN CONSTRUCTION'}}
# {'_id': 866, 'name': {'contractors_business_name': 'ADRIATIC COAST PLUMBING'}}
# {'_id': 867, 'name': {'contractors_business_name': 'ADRIEN VINCENT SEVERO'}}
# {'_id': 868, 'name': {'contractors_business_name': "ADRI'S PLUMBING"}}
# {'_id': 869, 'name': {'contractors_business_name': 'ADRIS PLUMBING INC'}}
# {'_id': 870, 'name': {'contractors_business_name': 'A D ROOFING'}}
# {'_id': 871, 'name': {'contractors_business_name': 'A D R SECURITY SYSTEMS INC'}}
# {'_id': 872, 'name': {'contractors_business_name': 'A & D SIGNS CORP'}}
# {'_id': 873, 'name': {'contractors_business_name': 'ADS PLUMBING AND CONSTRUCTION'}}
# {'_id': 874, 'name': {'contractors_business_name': 'A D T LECTRIC'}}
# {'_id': 875, 'name': {'contractors_business_name': 'ADT LLC'}}
# {'_id': 876, 'name': {'contractors_business_name': 'ADT SECURITY SERVICES'}}
# {'_id': 877, 'name': {'contractors_business_name': 'ADU CONSTRUCTION CONTRACTING'}}
# {'_id': 878, 'name': {'contractors_business_name': 'ADVANCE BUILDING PROTECTION INC'}}
# {'_id': 879, 'name': {'contractors_business_name': 'ADVANCE CONSTRUCTION'}}
# {'_id': 880, 'name': {'contractors_business_name': 'ADVANCE CONSTRUCTION GROUP INC'}}
# {'_id': 881, 'name': {'contractors_business_name': 'ADVANCED ACCESS CONTROLS'}}
# {'_id': 882, 'name': {'contractors_business_name': 'ADVANCED ACCESS CONTROLS INC'}}
# {'_id': 883, 'name': {'contractors_business_name': 'ADVANCED A / C & HEATING INC'}}
# {'_id': 884, 'name': {'contractors_business_name': 'ADVANCED AIR CONDITIONING AND HEATING COMPANY'}}
# {'_id': 885, 'name': {'contractors_business_name': 'ADVANCED AIRE MOVEMENT'}}
# {'_id': 886, 'name': {'contractors_business_name': 'ADVANCED AIR & MECHANICAL HVAC'}}
# {'_id': 887, 'name': {'contractors_business_name': 'ADVANCED ALARM INC'}}
# {'_id': 888, 'name': {'contractors_business_name': 'ADVANCED ALARMS'}}
# {'_id': 889, 'name': {'contractors_business_name': 'ADVANCED ALARMS INC'}}
# {'_id': 890, 'name': {'contractors_business_name': 'ADVANCED AQUATIC TECHNOLOGY INC'}}
# {'_id': 891, 'name': {'contractors_business_name': 'ADVANCED AUTOMATED SYSTEMS INC'}}
# {'_id': 892, 'name': {'contractors_business_name': 'ADVANCED AUTOMATED SYSTEMS INC.'}}
# {'_id': 893, 'name': {'contractors_business_name': 'ADVANCED B C INC'}}
# {'_id': 894, 'name': {'contractors_business_name': 'ADVANCED BUILDING DEVELOPMENT & CONSTRUCTION INC'}}
# {'_id': 895, 'name': {'contractors_business_name': 'ADVANCED BUSINESS COMMUNICATIONS'}}
# {'_id': 896, 'name': {'contractors_business_name': 'ADVANCED CABLE & COMMUNICATIONS INC'}}
# {'_id': 897, 'name': {'contractors_business_name': 'ADVANCED CABLE SOLUTIONS INC'}}
# {'_id': 898, 'name': {'contractors_business_name': 'ADVANCED CENTRIFUGAL SYSTEMS INC'}}
# {'_id': 899, 'name': {'contractors_business_name': 'ADVANCED CLIMATE CONTROL HEATING & AIR CONDITIONING'}}
# {'_id': 900, 'name': {'contractors_business_name': 'ADVANCED COMFORT INCORPORATED'}}
# {'_id': 901, 'name': {'contractors_business_name': 'ADVANCED COMFORT SOLUTIONS INC'}}
# {'_id': 902, 'name': {'contractors_business_name': 'ADVANCED COMMUNICATIONS SOLUTIONS INC'}}
# {'_id': 903, 'name': {'contractors_business_name': 'ADVANCED CONSTRUCTION'}}
# {'_id': 904, 'name': {'contractors_business_name': 'ADVANCED CONSTRUCTION & RESTORATION'}}
# {'_id': 905, 'name': {'contractors_business_name': 'ADVANCED CONSTRUCTION TECH'}}
# {'_id': 906, 'name': {'contractors_business_name': 'ADVANCED CONSTRUCTION TECHNOLOGIES'}}
# {'_id': 907, 'name': {'contractors_business_name': 'ADVANCED CONTRACTORS INC'}}
# {'_id': 908, 'name': {'contractors_business_name': 'ADVANCED COOLING AND HEATING'}}
# {'_id': 909, 'name': {'contractors_business_name': 'ADVANCED DESIGN TO FINISH'}}
# {'_id': 910, 'name': {'contractors_business_name': 'ADVANCED DEVELOPMENT'}}
# {'_id': 911, 'name': {'contractors_business_name': 'ADVANCED ELECTRIC'}}
# {'_id': 912, 'name': {'contractors_business_name': 'ADVANCED ELECTRICAL CONTRACTORS'}}
# {'_id': 913, 'name': {'contractors_business_name': 'ADVANCED ELECTRICAL INNOVATIONS'}}
# {'_id': 914, 'name': {'contractors_business_name': 'ADVANCED ELECTRICAL & LIGHTING SERVICES'}}
# {'_id': 915, 'name': {'contractors_business_name': 'ADVANCED ELECTRICAL PROTECTION INC'}}
# {'_id': 916, 'name': {'contractors_business_name': 'ADVANCED ELECTRICAL SERVICES INC'}}
# {'_id': 917, 'name': {'contractors_business_name': 'ADVANCED FIREPLACES CONSTRUCTION'}}
# {'_id': 918, 'name': {'contractors_business_name': 'ADVANCED FIREPLACES LLC'}}
# {'_id': 919, 'name': {'contractors_business_name': 'ADVANCED FIRE PROTECTION INC'}}
# {'_id': 920, 'name': {'contractors_business_name': 'ADVANCED GENERAL CONSTRUCTION'}}
# {'_id': 921, 'name': {'contractors_business_name': 'ADVANCED HEATING AND AIR CONDITIONING CO INC'}}
# {'_id': 922, 'name': {'contractors_business_name': 'ADVANCED HEATING AND COOLING INC'}}
# {'_id': 923, 'name': {'contractors_business_name': 'ADVANCED IMPROVEMENTS INC'}}
# {'_id': 924, 'name': {'contractors_business_name': 'ADVANCED INNOVATIVE CONSTRUCTION'}}
# {'_id': 925, 'name': {'contractors_business_name': 'ADVANCED LANDSCAPE 2000 INC'}}
# {'_id': 926, 'name': {'contractors_business_name': 'ADVANCED MAINTENANCE INC'}}
# {'_id': 927, 'name': {'contractors_business_name': 'ADVANCED MECHANICAL'}}
# {'_id': 928, 'name': {'contractors_business_name': 'ADVANCED MEDICAL BUILDERS INC'}}
# {'_id': 929, 'name': {'contractors_business_name': 'ADVANCED NETWORK SYSTEMS INC'}}
# {'_id': 930, 'name': {'contractors_business_name': 'ADVANCED PLUMBING SOLUTIONS INC'}}
# {'_id': 931, 'name': {'contractors_business_name': 'ADVANCED PLUMBING TECHNOLOGIES'}}
# {'_id': 932, 'name': {'contractors_business_name': 'ADVANCED POWER SYSTEMS'}}
# {'_id': 933, 'name': {'contractors_business_name': 'ADVANCED PROPERTY SOLUTIONS INC'}}
# {'_id': 934, 'name': {'contractors_business_name': 'ADVANCED REMODELING & CONSTRUCTION'}}
# {'_id': 935, 'name': {'contractors_business_name': 'ADVANCED ROOFING SYSTEMS'}}
# {'_id': 936, 'name': {'contractors_business_name': 'ADVANCED ROOFING SYSTEMS INC'}}
# {'_id': 937, 'name': {'contractors_business_name': 'ADVANCED ROOF SYSTEMS & CONSTRUCTION INC'}}
# {'_id': 938, 'name': {'contractors_business_name': 'ADVANCED SIGNS BY NICK'}}
# {'_id': 939, 'name': {'contractors_business_name': 'ADVANCED SOLAR ELECTRIC INC'}}
# {'_id': 940, 'name': {'contractors_business_name': 'ADVANCED STRUCTURAL BUILDERS INC'}}
# {'_id': 941, 'name': {'contractors_business_name': 'ADVANCED STRUCTURES INC'}}
# {'_id': 942, 'name': {'contractors_business_name': 'ADVANCED TECHNOLOGY'}}
# {'_id': 943, 'name': {'contractors_business_name': 'ADVANCED TECHNOLOGY AIR SYSTEMS'}}
# {'_id': 944, 'name': {'contractors_business_name': 'ADVANCE ELECTRIC'}}
# {'_id': 945, 'name': {'contractors_business_name': 'ADVANCE ELECTRICAL SERVICE'}}
# {'_id': 946, 'name': {'contractors_business_name': 'ADVANCE ELECTRICAL SERVICES INC'}}
# {'_id': 947, 'name': {'contractors_business_name': 'ADVANCE ELECTRIC & CONSTRUCTION'}}
# {'_id': 948, 'name': {'contractors_business_name': 'ADVANCE FIRE PROTECTION CO INC'}}
# {'_id': 949, 'name': {'contractors_business_name': 'ADVANCE GLAZING SOLUTIONS INC'}}
# {'_id': 950, 'name': {'contractors_business_name': 'ADVANCE HOME IMPROVEMENT INC'}}
# {'_id': 951, 'name': {'contractors_business_name': 'ADVANCE LIGHTING AND ELECTRIC'}}
# {'_id': 952, 'name': {'contractors_business_name': 'ADVANCE LIGHTING & ELECTRIC INC'}}
# {'_id': 953, 'name': {'contractors_business_name': 'ADVANCE NRG - H.V.A.C.'}}
# {'_id': 954, 'name': {'contractors_business_name': 'ADVANCE PLUMBING'}}
# {'_id': 955, 'name': {'contractors_business_name': 'ADVANCE REMODELING AND PROPERTY SERVICES'}}
# {'_id': 956, 'name': {'contractors_business_name': 'ADVANCE SOUND & FIRE INC'}}
# {'_id': 957, 'name': {'contractors_business_name': 'ADVANCO FIRE PROTECTION INC'}}
# {'_id': 958, 'name': {'contractors_business_name': 'ADVANED POLHESAR LIGHTING'}}
# {'_id': 959, 'name': {'contractors_business_name': 'ADVANTAGE AIR CONDITIONING'}}
# {'_id': 960, 'name': {'contractors_business_name': 'ADVANTAGE AIR INC'}}
# {'_id': 961, 'name': {'contractors_business_name': 'ADVANTAGE AUDIO VIDEO'}}
# {'_id': 962, 'name': {'contractors_business_name': 'ADVANTAGE DESIGN & BUILDING COMPANY'}}
# {'_id': 963, 'name': {'contractors_business_name': 'ADVANTAGE ELECTRICAL SERVICES INC'}}
# {'_id': 964, 'name': {'contractors_business_name': 'ADVANTAGE FIRE PROTECTION'}}
# {'_id': 965, 'name': {'contractors_business_name': 'ADVANTAGE H V A C'}}
# {'_id': 966, 'name': {'contractors_business_name': 'ADVANTAGE PLUMBING'}}
# {'_id': 967, 'name': {'contractors_business_name': 'ADVANTAGE PROJECT BUILDERS'}}
# {'_id': 968, 'name': {'contractors_business_name': 'ADVANTAGESIGNSERVICE INC'}}
# {'_id': 969, 'name': {'contractors_business_name': 'ADVENT COMPANIES INC'}}
# {'_id': 970, 'name': {'contractors_business_name': 'ADY SERVICE'}}
# {'_id': 971, 'name': {'contractors_business_name': 'A E AUDIO VIDEO'}}
# {'_id': 972, 'name': {'contractors_business_name': 'A E C'}}
# {'_id': 973, 'name': {'contractors_business_name': 'A E CARLSON CONSTRUCTION INC'}}
# {'_id': 974, 'name': {'contractors_business_name': 'A E C O CONSTRUCTION ENTERPRISE INC'}}
# {'_id': 975, 'name': {'contractors_business_name': 'A E CONSTRUCTION'}}
# {'_id': 976, 'name': {'contractors_business_name': 'A & E CONSTRUCTION & PAINTING INC'}}
# {'_id': 977, 'name': {'contractors_business_name': 'A E CONSTRUCTION SERVICES INC'}}
# {'_id': 978, 'name': {'contractors_business_name': 'A & E CONSTRUCTION TEAM INC'}}
# {'_id': 979, 'name': {'contractors_business_name': 'A E D CONTRACTORS'}}
# {'_id': 980, 'name': {'contractors_business_name': 'AEDIFICE REX INC'}}
# {'_id': 981, 'name': {'contractors_business_name': 'A E ELECTRICAL CO'}}
# {'_id': 982, 'name': {'contractors_business_name': 'A E ENTERPRISES'}}
# {'_id': 983, 'name': {'contractors_business_name': 'A & E HEATING AND AIR CONDITIONING'}}
# {'_id': 984, 'name': {'contractors_business_name': 'A E I GENERAL CONTRACTORS'}}
# {'_id': 985, 'name': {'contractors_business_name': 'A E K CONSTRUCTION'}}
# {'_id': 986, 'name': {'contractors_business_name': 'A + ELECTRIC'}}
# {'_id': 987, 'name': {'contractors_business_name': 'A + ELECTRICIANS'}}
# {'_id': 988, 'name': {'contractors_business_name': 'A + ELECTRIC & PLUMBING'}}
# {'_id': 989, 'name': {'contractors_business_name': 'AEPHIL PACIFIC CORP'}}
# {'_id': 990, 'name': {'contractors_business_name': 'AEPHIL PACIFIC CORP DBA PACIFIC COAST ELECTRIC'}}
# {'_id': 991, 'name': {'contractors_business_name': 'A & E PLUMBING'}}
# {'_id': 992, 'name': {'contractors_business_name': 'AERIOCONNECT INC'}}
# {'_id': 993, 'name': {'contractors_business_name': 'AERO AUTOMATIC SPRINKLER COMPANY'}}
# {'_id': 994, 'name': {'contractors_business_name': 'AERO BRIDGEWORKS INC'}}
# {'_id': 995, 'name': {'contractors_business_name': 'AERODYNAMIX'}}
# {'_id': 996, 'name': {'contractors_business_name': 'A E ROOFING'}}
# {'_id': 997, 'name': {'contractors_business_name': 'AEROSCOPIC ENVIRONMENTAL INC'}}
# {'_id': 998, 'name': {'contractors_business_name': 'AEROSTAR CONSTRUCTION INC'}}
# {'_id': 999, 'name': {'contractors_business_name': 'AES MECHANICAL SERVICES GROUP INC'}}
# {'_id': 1000, 'name': {'contractors_business_name': 'A E S PLUMBING'}}
# {'_id': 1001, 'name': {'contractors_business_name': 'AET ENTERPRISES'}}
